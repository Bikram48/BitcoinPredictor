# %%
import pandas as pd
import calendar
import matplotlib.pyplot as plt

# %%
csv_files = ["/Users/bikram/Downloads/BTC-2017min.csv", 
             "/Users/bikram/Downloads/BTC-2018min.csv",
            "/Users/bikram/Downloads/BTC-2019min.csv",
            "/Users/bikram/Downloads/BTC-2020min.csv",
            "BTC-2021min.csv"]

dfs = []

for file in csv_files:
    dfs.append(pd.read_csv(file))
    
df = pd.concat(dfs, ignore_index=True)

# %%
df.head(5)
# Out:
#          unix                 date   symbol      open      high       low  \
# 0  1514764740  2017-12-31 23:59:00  BTC/USD  13913.28  13913.28  13867.18
# 1  1514764680  2017-12-31 23:58:00  BTC/USD  13913.26  13953.83  13884.69
# 2  1514764620  2017-12-31 23:57:00  BTC/USD  13908.73  13913.26  13874.99
# 3  1514764560  2017-12-31 23:56:00  BTC/USD  13827.00  13908.69  13827.00
# 4  1514764500  2017-12-31 23:55:00  BTC/USD  13825.05  13825.05  13825.05
#
#       close  Volume BTC    Volume USD
# 0  13880.00    0.591748   8213.456549
# 1  13953.77    1.398784  19518.309658
# 2  13913.26    0.775012  10782.944294
# 3  13859.58    0.666459   9236.841134
# 4  13825.05    0.065501    905.560130

# %%
df.tail(5)
# Out:
#                unix                 date   symbol      open      high  \
# 2675296  1609459500  2021-01-01 00:05:00  BTC/USD  29021.86  29023.38
# 2675297  1609459440  2021-01-01 00:04:00  BTC/USD  29048.13  29057.73
# 2675298  1609459380  2021-01-01 00:03:00  BTC/USD  29037.68  29069.39
# 2675299  1609459320  2021-01-01 00:02:00  BTC/USD  29069.80  29073.02
# 2675300  1609459260  2021-01-01 00:01:00  BTC/USD  29007.31  29086.90
#
#               low     close  Volume BTC     Volume USD
# 2675296  28982.33  28999.50    1.062360   30807.899250
# 2675297  29035.61  29045.19    1.446538   42014.959434
# 2675298  29019.00  29048.13    2.189621   63604.382387
# 2675299  29028.14  29035.89    3.030301   87987.499279
# 2675300  29007.31  29083.47   14.561951  423512.060397

# %%
df.shape
# Out:
# (2675301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2675301 entries, 0 to 2675300
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   unix        int64
#  1   date        object
#  2   symbol      object
#  3   open        float64
#  4   high        float64
#  5   low         float64
#  6   close       float64
#  7   Volume BTC  float64
#  8   Volume USD  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 183.7+ MB

# %%
df.describe()
# Out:
#                unix          open          high           low         close  \
# count  2.675301e+06  2.675301e+06  2.675301e+06  2.675301e+06  2.675301e+06
# mean   1.564041e+09  1.620993e+04  1.621988e+04  1.619961e+04  1.620996e+04
# std    4.707622e+07  1.742228e+04  1.743201e+04  1.741236e+04  1.742244e+04
# min    1.483229e+09  7.520000e+02  7.528100e+02  7.513400e+02  7.520400e+02
# 25%    1.523358e+09  5.599040e+03  5.602000e+03  5.594980e+03  5.598880e+03
# 50%    1.563488e+09  8.703120e+03  8.709860e+03  8.696910e+03  8.702810e+03
# 75%    1.603618e+09  1.550000e+04  1.551000e+04  1.548793e+04  1.550000e+04
# max    1.646106e+09  6.900000e+04  6.900000e+04  6.879999e+04  6.900000e+04
#
#          Volume BTC    Volume USD
# count  2.675301e+06  2.675301e+06
# mean   6.130515e+00  7.079403e+04
# std    1.629300e+01  2.030353e+05
# min    0.000000e+00  0.000000e+00
# 25%    2.518954e-01  2.244546e+03
# 50%    1.467694e+00  1.466467e+04
# 75%    5.507826e+00  5.865908e+04
# max    1.616060e+03  1.396792e+07

# %% [markdown]
# <p><b>Drop the column unix</b></p>

# %%
df = df.drop("unix", axis=1)

# %% [markdown]
# <p><b>Convert dates to datetime and format date to year-month-day</b></p>

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.head()
# Out:
#                  date   symbol      open      high       low     close  \
# 0 2017-12-31 23:59:00  BTC/USD  13913.28  13913.28  13867.18  13880.00
# 1 2017-12-31 23:58:00  BTC/USD  13913.26  13953.83  13884.69  13953.77
# 2 2017-12-31 23:57:00  BTC/USD  13908.73  13913.26  13874.99  13913.26
# 3 2017-12-31 23:56:00  BTC/USD  13827.00  13908.69  13827.00  13859.58
# 4 2017-12-31 23:55:00  BTC/USD  13825.05  13825.05  13825.05  13825.05
#
#    Volume BTC    Volume USD
# 0    0.591748   8213.456549
# 1    1.398784  19518.309658
# 2    0.775012  10782.944294
# 3    0.666459   9236.841134
# 4    0.065501    905.560130

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2675301 entries, 0 to 2675300
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   date        datetime64[ns]
#  1   symbol      object
#  2   open        float64
#  3   high        float64
#  4   low         float64
#  5   close       float64
#  6   Volume BTC  float64
#  7   Volume USD  float64
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 163.3+ MB

# %% [markdown]
# #### Check for null values

# %%
df.isnull().any()
# Out:
# date          False
# symbol        False
# open          False
# high          False
# low           False
# close         False
# Volume BTC    False
# Volume USD    False
# dtype: bool

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 2017 Analysis

# %% [markdown]
# <p><b>Extracting 2017 data</b></p>

# %%
df_2017 = df[(df['date']>="2017-01-01") & (df['date']<'2018-01-01')]
df_2017
# Out:
#                       date   symbol      open      high       low     close  \
# 0      2017-12-31 23:59:00  BTC/USD  13913.28  13913.28  13867.18  13880.00
# 1      2017-12-31 23:58:00  BTC/USD  13913.26  13953.83  13884.69  13953.77
# 2      2017-12-31 23:57:00  BTC/USD  13908.73  13913.26  13874.99  13913.26
# 3      2017-12-31 23:56:00  BTC/USD  13827.00  13908.69  13827.00  13859.58
# 4      2017-12-31 23:55:00  BTC/USD  13825.05  13825.05  13825.05  13825.05
# ...                    ...      ...       ...       ...       ...       ...
# 525594 2017-01-01 00:05:00  BTC/USD    966.43    966.43    966.43    966.43
# 525595 2017-01-01 00:04:00  BTC/USD    966.37    966.37    966.37    966.37
# 525596 2017-01-01 00:03:00  BTC/USD    966.37    966.37    966.37    966.37
# 525597 2017-01-01 00:02:00  BTC/USD    966.16    966.37    966.16    966.37
# 525598 2017-01-01 00:01:00  BTC/USD    966.34    966.34    966.34    966.34
#
#         Volume BTC    Volume USD
# 0         0.591748   8213.456549
# 1         1.398784  19518.309658
# 2         0.775012  10782.944294
# 3         0.666459   9236.841134
# 4         0.065501    905.560130
# ...            ...           ...
# 525594    0.107000    103.408010
# 525595    0.000000      0.000000
# 525596    0.000000      0.000000
# 525597    8.087376   7815.397864
# 525598    7.610000   7353.847400
#
# [525599 rows x 8 columns]

# %% [markdown]
# <p><b>Sort the data by date in ascending order</b></p>

# %%
df_2017 = df_2017.sort_values(by="date")
df_2017
# Out:
#                       date   symbol      open      high       low     close  \
# 525598 2017-01-01 00:01:00  BTC/USD    966.34    966.34    966.34    966.34
# 525597 2017-01-01 00:02:00  BTC/USD    966.16    966.37    966.16    966.37
# 525596 2017-01-01 00:03:00  BTC/USD    966.37    966.37    966.37    966.37
# 525595 2017-01-01 00:04:00  BTC/USD    966.37    966.37    966.37    966.37
# 525594 2017-01-01 00:05:00  BTC/USD    966.43    966.43    966.43    966.43
# ...                    ...      ...       ...       ...       ...       ...
# 4      2017-12-31 23:55:00  BTC/USD  13825.05  13825.05  13825.05  13825.05
# 3      2017-12-31 23:56:00  BTC/USD  13827.00  13908.69  13827.00  13859.58
# 2      2017-12-31 23:57:00  BTC/USD  13908.73  13913.26  13874.99  13913.26
# 1      2017-12-31 23:58:00  BTC/USD  13913.26  13953.83  13884.69  13953.77
# 0      2017-12-31 23:59:00  BTC/USD  13913.28  13913.28  13867.18  13880.00
#
#         Volume BTC    Volume USD
# 525598    7.610000   7353.847400
# 525597    8.087376   7815.397864
# 525596    0.000000      0.000000
# 525595    0.000000      0.000000
# 525594    0.107000    103.408010
# ...            ...           ...
# 4         0.065501    905.560130
# 3         0.666459   9236.841134
# 2         0.775012  10782.944294
# 1         1.398784  19518.309658
# 0         0.591748   8213.456549
#
# [525599 rows x 8 columns]

# %% [markdown]
# <p><b> convert the numerical representation of months to their corresponding three-letter abbreviations (e.g., "Jan" for January) and store them in a new column called "month" for analysis. </b></p>

# %%
df_2017["month"] = df_2017['date'].dt.month
df_2017['month'] = df_2017['date'].dt.month.apply(lambda x: calendar.month_abbr[x])
df_2017
# Out:
#                       date   symbol      open      high       low     close  \
# 525598 2017-01-01 00:01:00  BTC/USD    966.34    966.34    966.34    966.34
# 525597 2017-01-01 00:02:00  BTC/USD    966.16    966.37    966.16    966.37
# 525596 2017-01-01 00:03:00  BTC/USD    966.37    966.37    966.37    966.37
# 525595 2017-01-01 00:04:00  BTC/USD    966.37    966.37    966.37    966.37
# 525594 2017-01-01 00:05:00  BTC/USD    966.43    966.43    966.43    966.43
# ...                    ...      ...       ...       ...       ...       ...
# 4      2017-12-31 23:55:00  BTC/USD  13825.05  13825.05  13825.05  13825.05
# 3      2017-12-31 23:56:00  BTC/USD  13827.00  13908.69  13827.00  13859.58
# 2      2017-12-31 23:57:00  BTC/USD  13908.73  13913.26  13874.99  13913.26
# 1      2017-12-31 23:58:00  BTC/USD  13913.26  13953.83  13884.69  13953.77
# 0      2017-12-31 23:59:00  BTC/USD  13913.28  13913.28  13867.18  13880.00
#
#         Volume BTC    Volume USD month
# 525598    7.610000   7353.847400   Jan
# 525597    8.087376   7815.397864   Jan
# 525596    0.000000      0.000000   Jan
# 525595    0.000000      0.000000   Jan
# 525594    0.107000    103.408010   Jan
# ...            ...           ...   ...
# 4         0.065501    905.560130   Dec
# 3         0.666459   9236.841134   Dec
# 2         0.775012  10782.944294   Dec
# 1         1.398784  19518.309658   Dec
# 0         0.591748   8213.456549   Dec
#
# [525599 rows x 9 columns]

# %% [markdown]
# <p><b>creating a bar graph comparing the open and close prices of the stock month-wise</b></p>

# %%
monthly_open_close_data = df_2017.groupby('month')[['open', 'close']].mean()
monthly_open_close_data = monthly_open_close_data.reindex(calendar.month_abbr[1:], axis=0)

monthly_open_close_data.plot(kind='bar')
plt.title("Average Open and Close Price Mont-Wise")
plt.xlabel("Month")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()
